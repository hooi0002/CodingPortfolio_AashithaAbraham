# %%
# Data Types (Python Literals)
# Integer - 1, 2, 3, 100, 200
# Strings - "Netflix", " ", "Programming made easy!"
# Float - 1.25, 3.14159
# Boolean - True, False (Computer Switch)

# Multiline-comments
"""
AAA
BBB
CCC
"""

import builtins
print(dir(builtins))

age = 10
Age = 20
landmark = "Merlion"
netWorth = 100.3541
isRaining = False

print(age)
print(type(age))
print(type(landmark))
print(type(isRaining))


# Math operations - +, -, *, /, //, **, %
# Multiplying two integers results in an int, and multiplying a number with a float results in a float.
# Unlike addition, subtraction, and multiplication, division with the / operator always returns a float
print(3 + 3)
print(3 - (-4))
print(3 * 3)
print(3 * 3.0)
print(3 / 3)
print(10 // 3)
print(3 ** 3) # power
print(3 % 2)
print(4 % 2)


# string concatenation
var1 = "100"
var2 = "300"
print(var1 + var2)

str1 = "Little"
str2 = "India"
print(str1 + str2)
print(str1, str2)
print(str1, str2, sep="🇸🇬")

# Requirements for a variable name
"""
1. No space in variable name
2. Cannot start with a number
3. Not a reserved keyword
"""


# String multiplication
print("+" + "-" * 50 + "+")
print(("|" + " " * 50 + "|\n") * 5, end="")
print("+" + "-" * 50 + "+")


"""
Print: 
+--------------------------------------------------+
|                                                  |
|                                                  |
|                       EROS                       |
|                                                  |
|                                                  |
+--------------------------------------------------+
"""
# Method 1
print("+" + "-" * 50 + "+")
print(("|" + " " * 50 + "|\n") * 2, end="")
print(("|" + " " * ((50 - 4) // 2) + "EROS" + " " * ((50 - 4) // 2) + "|"))
print(("|" + " " * 50 + "|\n") * 2, end="")
print("+" + "-" * 50 + "+")

print("\r")

# Method 2
print("+" + "-" * 50 + "+")
print(("|" + " " * 50 + "|\n") * 2, ("|" + " " * 50 + "|\n") * 2, sep=("|" + " " * ((50 - 4) // 2) + "EROS" + " " * ((50 - 4) // 2) + "|\n"), end="")
print("+" + "-" * 50 + "+")
